# %%
pip install fredapi
# Out:
# Collecting fredapi
#   Downloading fredapi-0.4.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pandas in e:\users\hp\anaconda3\lib\site-packages (from fredapi) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in e:\users\hp\anaconda3\lib\site-packages (from pandas->fredapi) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in e:\users\hp\anaconda3\lib\site-packages (from pandas->fredapi) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in e:\users\hp\anaconda3\lib\site-packages (from pandas->fredapi) (1.19.5)
# Requirement already satisfied: six>=1.5 in e:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->fredapi) (1.15.0)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from fredapi import Fred
fred = Fred(api_key = "79ee0d54aa94f21b8d8252471c6ea20a")

# %%
import pandas as pd
pd.options.display.max_colwidth = 60

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
figsize(20, 5)

# %%
s = fred.get_series('SP500', observation_start='2014-09-02', observation_end='2014-09-05')
s.tail()
# Out:
# 2014-09-02    2002.28
# 2014-09-03    2000.72
# 2014-09-04    1997.65
# 2014-09-05    2007.71
# dtype: float64

# %%
s = fred.get_series('SP500', observation_start='1/31/2014')
s.tail()
# Out:
# 2021-12-29    4793.06
# 2021-12-30    4778.73
# 2021-12-31    4766.18
# 2022-01-03    4796.56
# 2022-01-04    4793.54
# dtype: float64

# %%
info = fred.get_series_info('PAYEMS')
info['title']
# Out:
# 'All Employees, Total Nonfarm'

# %%
personal_income_series = fred.search_by_release(175, limit=5, order_by='popularity', sort_order='desc')

# %%
personal_income_series['title']
# Out:
# series id
# PCPI06037             Per Capita Personal Income in Los Angeles County, CA
# DALL148PCPI    Per Capita Personal Income in Dallas-Fort Worth-Arlingto...
# PHOE004PCPI    Per Capita Personal Income in Phoenix-Mesa-Scottsdale, A...
# ATLA013PCPI    Per Capita Personal Income in Atlanta-Sandy Springs-Rosw...
# CHIC917PCPI    Per Capita Personal Income in Chicago-Naperville-Elgin, ...
# Name: title, dtype: object

# %%
df = {}
df['SF'] = fred.get_series('PCPI06075')
df['NY'] = fred.get_series('PCPI36061')
df['DC'] = fred.get_series('PCPI11001')
df = pd.DataFrame(df)
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = fred.search_by_category(101, limit=10, order_by='popularity', sort_order='desc')
df['title']
# Out:
# series id
# SLOAS                                      Student Loans Owned and Securitized
# TOTALSL                            Total Consumer Credit Owned and Securitized
# TERMCBAUTO48NS     Finance Rate on Consumer Installment Loans at Commercial...
# TERMCBCCALLNS      Commercial Bank Interest Rate on Credit Card Plans, All ...
# RIFLPBCIANM60NM    Finance Rate on Consumer Installment Loans at Commercial...
# TERMCBPER24NS      Finance Rate on Personal Loans at Commercial Banks, 24 M...
# MVLOAS                               Motor Vehicle Loans Owned and Securitized
# REVOLSL                        Revolving Consumer Credit Owned and Securitized
# TERMCBCCINTNS      Commercial Bank Interest Rate on Credit Card Plans, Acco...
# TOTALSLAR                              Percent Change of Total Consumer Credit
# Name: title, dtype: object

# %%
state_df = df[~df['title'].str.startswith('Per Capita Personal Income in the')]

# %%
len(state_df)
# Out:
# 10

# %%
state_df.id.str[:2]
# Out:
# series id
# SLOAS              SL
# TOTALSL            TO
# TERMCBAUTO48NS     TE
# TERMCBCCALLNS      TE
# RIFLPBCIANM60NM    RI
# TERMCBPER24NS      TE
# MVLOAS             MV
# REVOLSL            RE
# TERMCBCCINTNS      TE
# TOTALSLAR          TO
# Name: id, dtype: object

# %%
income_by_state = {}
for series_id in state_df.index:
    income_by_state[series_id[:2]] = fred.get_series(series_id)

# %%
income_by_state = pd.DataFrame(income_by_state)

# %%
income_by_state.index[-1].plot(kind='bar')
plt.title('Per Capita Personal Income by State')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-0cf095a3fcb6> in <module>
# ----> 1 income_by_state.index[-1].plot(kind='bar')
#       2 plt.title('Per Capita Personal Income by State')
#
# AttributeError: 'Timestamp' object has no attribute 'plot'

# %%
import os
import sys
import rdflib

# %%
pip install rdflib
# Out:
# Collecting rdflib
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
# Requirement already satisfied: setuptools in e:\users\hp\anaconda3\lib\site-packages (from rdflib) (58.2.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: pyparsing in e:\users\hp\anaconda3\lib\site-packages (from rdflib) (2.4.7)
# Requirement already satisfied: six in e:\users\hp\anaconda3\lib\site-packages (from isodate->rdflib) (1.15.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-6.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from flufl.enum import Enum
from rdflib import plugin
from rdflib.serializer import Serializer
from rdflib.plugins.memory import IOMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-eeca7d54696c> in <module>
# ----> 1 from flufl.enum import Enum
#       2 from rdflib import plugin
#       3 from rdflib.serializer import Serializer
#       4 from rdflib.plugins.memory import IOMemory
#
# ModuleNotFoundError: No module named 'flufl'

# %%
pip install flufl.lock
# Out:
# Collecting flufl.lock
#   Downloading flufl.lock-6.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting atpublic
#   Downloading atpublic-2.3.tar.gz (16 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: psutil in e:\users\hp\anaconda3\lib\site-packages (from flufl.lock) (5.8.0)
# Building wheels for collected packages: flufl.lock, atpublic
#   Building wheel for flufl.lock (setup.py): started
#   Building wheel for flufl.lock (setup.py): finished with status 'done'
#   Created wheel for flufl.lock: filename=flufl.lock-6.0-py3-none-any.whl size=11996 sha256=8be2b9660d8d2c6863ed7ec4c8b669571098387c4be01642b9c4dbd5bae346d7
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\54\48\48\5caf7b125cc0213ff5336ab5bb0672deebb1326ff2e5ca2e24
#   Building wheel for atpublic (setup.py): started
#   Building wheel for atpublic (setup.py): finished with status 'done'
#   Created wheel for atpublic: filename=atpublic-2.3-py3-none-any.whl size=5033 sha256=4852c1e94d3b69e4dc0d93c45388617cb75c13a1bd194e5f35eb31b7bed3e661
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\f3\a4\10\e7e5bb869828997204dc4a7ce0760132c7d6d5ae47a5e58b90
# Successfully built flufl.lock atpublic
# Installing collected packages: atpublic, flufl.lock
# Successfully installed atpublic-2.3 flufl.lock-6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from flufl.enum import Enum
from rdflib import plugin
from rdflib.serializer import Serializer
from rdflib.plugins.memory import IOMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-eeca7d54696c> in <module>
# ----> 1 from flufl.enum import Enum
#       2 from rdflib import plugin
#       3 from rdflib.serializer import Serializer
#       4 from rdflib.plugins.memory import IOMemory
#
# ModuleNotFoundError: No module named 'flufl.enum'

# %%
pip install flufl.enum
# Out:
# Collecting flufl.enum
#   Downloading flufl.enum-4.1.1.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: flufl.enum
#   Building wheel for flufl.enum (setup.py): started
#   Building wheel for flufl.enum (setup.py): finished with status 'done'
#   Created wheel for flufl.enum: filename=flufl.enum-4.1.1-py3-none-any.whl size=27590 sha256=7f00a9c4629d7b3db15ef29448134c3a5e6b4efefb446b2e1e1b80276e627234
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\10\95\6e\789876efd8638cf4b09c320ec8e0907b4f046b9ace33f8000c
# Successfully built flufl.enum
# Installing collected packages: flufl.enum
# Successfully installed flufl.enum-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from flufl.enum import Enum
from rdflib import plugin
from rdflib.serializer import Serializer
from rdflib.plugins.memory import IOMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-eeca7d54696c> in <module>
#       2 from rdflib import plugin
#       3 from rdflib.serializer import Serializer
# ----> 4 from rdflib.plugins.memory import IOMemory
#
# ModuleNotFoundError: No module named 'rdflib.plugins.memory'

# %%
pip install rdf.plugins.stores.iomemory
# Out:
# Collecting rdf.plugins.stores.iomemory
#   Using cached rdf.plugins.stores.iomemory-0.9a1.tar.gz (4.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'E:\Users\HP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-ybom2wtu\\rdf-plugins-stores-iomemory_a879a7af03a243c09d9a145d11d924eb\\setup.py'"'"'; __file__='"'"'C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-ybom2wtu\\rdf-plugins-stores-iomemory_a879a7af03a243c09d9a145d11d924eb\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\HP\AppData\Local\Temp\pip-pip-egg-info-ehh47xh7'
#        cwd: C:\Users\HP\AppData\Local\Temp\pip-install-ybom2wtu\rdf-plugins-stores-iomemory_a879a7af03a243c09d9a145d11d924eb\
#   Complete output (31 lines):
#   Downloading http://pypi.python.org/packages/source/d/distribute/distribute-0.6.14.tar.gz
#   Traceback (most recent call last):
#     File "E:\Users\HP\anaconda3\lib\site-packages\ez_setup.py", line 143, in use_setuptools
#       raise ImportError
#   ImportError
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\HP\AppData\Local\Temp\pip-install-ybom2wtu\rdf-plugins-stores-iomemory_a879a7af03a243c09d9a145d11d924eb\setup.py", line 2, in <module>
#       use_setuptools()
#     File "E:\Users\HP\anaconda3\lib\site-packages\ez_setup.py", line 145, in use_setuptools
#       return _do_download(version, download_base, to_dir, download_delay)
#     File "E:\Users\HP\anaconda3\lib\site-packages\ez_setup.py", line 123, in _do_download
#       tarball = download_setuptools(version, download_base,
#     File "E:\Users\HP\anaconda3\lib\site-packages\ez_setup.py", line 193, in download_setuptools
#       src = urlopen(url)
#     File "E:\Users\HP\anaconda3\lib\urllib\request.py", line 222, in urlopen
#       return opener.open(url, data, timeout)
#     File "E:\Users\HP\anaconda3\lib\urllib\request.py", line 531, in open
#       response = meth(req, response)
#     File "E:\Users\HP\anaconda3\lib\urllib\request.py", line 640, in http_response
#       response = self.parent.error(
#     File "E:\Users\HP\anaconda3\lib\urllib\request.py", line 569, in error
#       return self._call_chain(*args)
#     File "E:\Users\HP\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#       result = func(*args)
#     File "E:\Users\HP\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#       raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   urllib.error.HTTPError: HTTP Error 403: SSL is required
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ce/61/e4d75dc791cda8dab8e5d7854d1ffe52febc4e9480f24b496af339921a72/rdf.plugins.stores.iomemory-0.9a1.tar.gz#sha256=e2bab2574f5dad5ba2a28e8bcad977b066227eb3b0e86b80c1a8f4527c683031 (from https://pypi.org/simple/rdf-plugins-stores-iomemory/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement rdf.plugins.stores.iomemory (from versions: 0.9a1)
# ERROR: No matching distribution found for rdf.plugins.stores.iomemory

# %%
pip install dflib.plugins.memory
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement dflib.plugins.memory (from versions: none)
# ERROR: No matching distribution found for dflib.plugins.memory

# %%
pip install rdf.plugins.stores.iomemory==0.9a1
# Out:
# Collecting rdf.plugins.stores.iomemory==0.9a1
#   Using cached rdf.plugins.stores.iomemory-0.9a1.tar.gz (4.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'E:\Users\HP\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-p4h_ot6b\\rdf-plugins-stores-iomemory_64655633cf1e47fabae3c17d6a3aab15\\setup.py'"'"'; __file__='"'"'C:\\Users\\HP\\AppData\\Local\\Temp\\pip-install-p4h_ot6b\\rdf-plugins-stores-iomemory_64655633cf1e47fabae3c17d6a3aab15\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\HP\AppData\Local\Temp\pip-pip-egg-info-kvunnhlo'
#        cwd: C:\Users\HP\AppData\Local\Temp\pip-install-p4h_ot6b\rdf-plugins-stores-iomemory_64655633cf1e47fabae3c17d6a3aab15\
#   Complete output (5 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\HP\AppData\Local\Temp\pip-install-p4h_ot6b\rdf-plugins-stores-iomemory_64655633cf1e47fabae3c17d6a3aab15\setup.py", line 1, in <module>
#       from ez_setup import use_setuptools
#   ModuleNotFoundError: No module named 'ez_setup'
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ce/61/e4d75dc791cda8dab8e5d7854d1ffe52febc4e9480f24b496af339921a72/rdf.plugins.stores.iomemory-0.9a1.tar.gz#sha256=e2bab2574f5dad5ba2a28e8bcad977b066227eb3b0e86b80c1a8f4527c683031 (from https://pypi.org/simple/rdf-plugins-stores-iomemory/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement rdf.plugins.stores.iomemory==0.9a1 (from versions: 0.9a1)
# ERROR: No matching distribution found for rdf.plugins.stores.iomemory==0.9a1

# %%
pip install setuptools
# Out:
# Requirement already satisfied: setuptools in e:\users\hp\anaconda3\lib\site-packages (58.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ez_setup
# Out:
# Collecting ez_setup
#   Downloading ez_setup-0.9.tar.gz (6.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: ez-setup
#   Building wheel for ez-setup (setup.py): started
#   Building wheel for ez-setup (setup.py): finished with status 'done'
#   Created wheel for ez-setup: filename=ez_setup-0.9-py3-none-any.whl size=11013 sha256=575c0d1af826f5eafd5ad0924c39e9a77c5c71d97bf7037a0a44577c099f2694
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\99\10\f0\d0b8db5bf513290d7f30f8d0fb836532af46782bae00146ee9
# Successfully built ez-setup
# Installing collected packages: ez-setup
# Successfully installed ez-setup-0.9
# Note: you may need to restart the kernel to use updated packages.
